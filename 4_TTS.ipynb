# %%
pip install elevenlabs
# Out:
# Collecting elevenlabs
#   Downloading elevenlabs-2.21.0-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: httpx>=0.21.2 in ./.venv/lib/python3.12/site-packages (from elevenlabs) (0.28.1)
# Requirement already satisfied: pydantic>=1.9.2 in ./.venv/lib/python3.12/site-packages (from elevenlabs) (2.12.3)
# Requirement already satisfied: pydantic-core>=2.18.2 in ./.venv/lib/python3.12/site-packages (from elevenlabs) (2.41.4)
# Requirement already satisfied: requests>=2.20 in ./.venv/lib/python3.12/site-packages (from elevenlabs) (2.32.5)
# Requirement already satisfied: typing_extensions>=4.0.0 in ./.venv/lib/python3.12/site-packages (from elevenlabs) (4.15.0)
# Requirement already satisfied: websockets>=11.0 in ./.venv/lib/python3.12/site-packages (from elevenlabs) (15.0.1)
# Requirement already satisfied: anyio in ./.venv/lib/python3.12/site-packages (from httpx>=0.21.2->elevenlabs) (4.11.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx>=0.21.2->elevenlabs) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.21.2->elevenlabs) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.12/site-packages (from httpx>=0.21.2->elevenlabs) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.21.2->elevenlabs) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=1.9.2->elevenlabs) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.12/site-packages (from pydantic>=1.9.2->elevenlabs) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.20->elevenlabs) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.20->elevenlabs) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.12/site-packages (from anyio->httpx>=0.21.2->elevenlabs) (1.3.1)
# Downloading elevenlabs-2.21.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 575.0 kB/s  0:00:01 eta 0:00:01
# Installing collected packages: elevenlabs
# Successfully installed elevenlabs-2.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, getpass

def set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

set_env("ELEVENLABS_API_KEY")

# %%
msg = "Yooo!! What's up ???"

# %%
voice_id = "T8lgQl6x5PSdhmmWx42m"
model_id = "eleven_flash_v2_5"

# %%
from elevenlabs.client import ElevenLabs
import os 

client = ElevenLabs(
    api_key = os.getenv("ELEVENLABS_API_KEY")
)

audio = client.text_to_speech.convert(
    text=msg,
    voice_id=voice_id,
    model_id=model_id,
)

audio_bytes = b"".join(audio)

# %%
with open("audio.mp3", "wb") as f:
    f.write(audio_bytes)

# %%
from IPython.display import Audio
Audio("audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
